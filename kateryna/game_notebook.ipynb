# %%
from datetime import datetime
import pandas as pd
from tabulate import tabulate

df = pd.read_csv("/Users/maxwellcorbin/vs_stuff/kateryna/vgsales.csv")
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000  \
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
s = df.groupby(["Publisher"]).Global_Sales.sum().sort_values(ascending=False)
print(s[s >= 10])
# Out:
# Publisher
# Nintendo                                  1786.56
# Electronic Arts                           1110.32
# Activision                                 727.46
# Sony Computer Entertainment                607.50
# Ubisoft                                    474.72
# Take-Two Interactive                       399.54
# THQ                                        340.77
# Konami Digital Entertainment               283.64
# Sega                                       272.99
# Namco Bandai Games                         254.09
# Microsoft Game Studios                     245.79
# Capcom                                     200.89
# Atari                                      157.22
# Warner Bros. Interactive Entertainment     153.89
# Square Enix                                145.18
# Disney Interactive Studios                 119.96
# Eidos Interactive                           98.98
# LucasArts                                   87.34
# Bethesda Softworks                          82.14
# ...

# %%
s = df.groupby(["Publisher"]).Global_Sales.sum().sort_values(ascending=False)
print(s[s >= 10])
# Out:
# Publisher
# Nintendo                                  1786.56
# Electronic Arts                           1110.32
# Activision                                 727.46
# Sony Computer Entertainment                607.50
# Ubisoft                                    474.72
# Take-Two Interactive                       399.54
# THQ                                        340.77
# Konami Digital Entertainment               283.64
# Sega                                       272.99
# Namco Bandai Games                         254.09
# Microsoft Game Studios                     245.79
# Capcom                                     200.89
# Atari                                      157.22
# Warner Bros. Interactive Entertainment     153.89
# Square Enix                                145.18
# Disney Interactive Studios                 119.96
# Eidos Interactive                           98.98
# LucasArts                                   87.34
# Bethesda Softworks                          82.14
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df["JP_rat"] = df.JP_Sales / df.Global_Sales
df.loc[df.JP_pct > 0.0, ["Name", "Platform", "JP_rat", "Global_Sales", "JP_Sales"]].sort_values(["JP_rat", "Global_Sales"], ascending=[True, False]).head(30)
# Out:
#                                         Name Platform    JP_rat  Global_Sales
# 68                              Just Dance 2      Wii  0.001050          9.52  \
# 101                Call of Duty: Black Ops 3     XOne  0.001370          7.30
# 179                          Madden NFL 2004      PS2  0.001912          5.23
# 193           Call of Duty: Advanced Warfare     XOne  0.001949          5.13
# 207         Guitar Hero III: Legends of Rock      PS2  0.002008          4.98
# 211                            Madden NFL 06      PS2  0.002037          4.91
# 72                                 Minecraft     X360  0.002174          9.20
# 237         Guitar Hero III: Legends of Rock     X360  0.002208          4.53
# 238                          Madden NFL 2005      PS2  0.002208          4.53
# 240                            Madden NFL 07      PS2  0.002227          4.49
# 247          Michael Jackson: The Experience      Wii  0.002262          4.42
# ...
